# %% [markdown]
# **Data Description**
# The data is from kaggel website, has 13 columns and 138 rows. The attributes are :
# 1. Trip ID
# 2. Destination
# 3. Start date
# 4. End date
# 5. Duration
# 6. Traveler name
# 7. Traveler age
# 8. Traveler gender
# 9. Traveler nationality
# 10. Accomodation type
# 11. Accomodation cost
# 12. Transportation Type
# 13. Transportation cost

# %%
pwd
# Out:
# '/content'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read the file
df=pd.read_csv('/content/Travel .csv')

# %%
df.head()
# Out:
#    Trip ID       Destination Start date   End date  Duration (days)  \
# 0        1        London, UK   5/1/2023   5/8/2023                7
# 1        2  Phuket, Thailand  6/15/2023  6/20/2023                5
# 2        3   Bali, Indonesia   7/1/2023   7/8/2023                7
# 3        4     New York, USA  8/15/2023  8/29/2023               14
# 4        5      Tokyo, Japan  9/10/2023  9/17/2023                7
#
#    Traveler name  Traveler age Traveler gender Traveler nationality  \
# 0     John Smith            35            Male             American
# 1       Jane Doe            28          Female             Canadian
# 2      David Lee            45            Male               Korean
# 3  Sarah Johnson            29          Female              British
# 4     Kim Nguyen            26          Female           Vietnamese
#
#   Accommodation type Accommodation cost Transportation type  \
# 0              Hotel               1200              Flight
# ...

# %%
df.tail()
# Out:
#      Trip ID             Destination Start date   End date  Duration (days)  \
# 132      135  Rio de Janeiro, Brazil   8/1/2023  8/10/2023                9
# 133      136       Vancouver, Canada  8/15/2023  8/21/2023                6
# 134      137       Bangkok, Thailand   9/1/2023   9/8/2023                7
# 135      138        Barcelona, Spain  9/15/2023  9/22/2023                7
# 136      139   Auckland, New Zealand  10/1/2023  10/8/2023                7
#
#        Traveler name  Traveler age Traveler gender Traveler nationality  \
# 132       Jose Perez            37            Male            Brazilian
# 133      Emma Wilson            29          Female             Canadian
# 134        Ryan Chen            34            Male              Chinese
# 135  Sofia Rodriguez            25          Female              Spanish
# 136    William Brown            39            Male        New Zealander
#
#     Accommodation type Accommodation cost Transportation type  \
# ...

# %%
df1=df.dropna()
df2=df1.head(10)

# %%
x=df2['Duration (days)']
y=df2['Transportation cost']
plt.scatter(x,y)

# %%
df.count()
# Out:
# Trip ID                 137
# Destination             137
# Start date              137
# End date                137
# Duration (days)         137
# Traveler name           137
# Traveler age            137
# Traveler gender         137
# Traveler nationality    137
# Accommodation type      137
# Accommodation cost      137
# Transportation type     136
# Transportation cost     136
# dtype: int64

# %%
df.describe()
# Out:
#           Trip ID  Duration (days)  Traveler age
# count  137.000000       137.000000    137.000000
# mean    69.562044         7.605839     33.175182
# std     40.256140         1.601276      7.145441
# min      1.000000         5.000000     20.000000
# 25%     35.000000         7.000000     28.000000
# 50%     69.000000         7.000000     31.000000
# 75%    104.000000         8.000000     38.000000
# max    139.000000        14.000000     60.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 136 entries, 0 to 136
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Trip ID               136 non-null    int64
#  1   Destination           136 non-null    object
#  2   Start date            136 non-null    object
#  3   End date              136 non-null    object
#  4   Duration (days)       136 non-null    int64
#  5   Traveler name         136 non-null    object
#  6   Traveler age          136 non-null    int64
#  7   Traveler gender       136 non-null    object
#  8   Traveler nationality  136 non-null    object
#  9   Accommodation type    136 non-null    object
#  10  Accommodation cost    136 non-null    object
#  11  Transportation type   136 non-null    object
#  12  Transportation cost   136 non-null    object
# dtypes: int64(3), object(10)
# memory usage: 14.9+ KB
